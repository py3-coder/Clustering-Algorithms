# %% [markdown]
# ### Author ~ Saurabh Kumar

# %% [markdown]
# # **Lets First UnderStand Clustering**

# %% [markdown]
# # **What is Clustering?**

# %% [markdown]
# ### Defination:
# * **Clustering is Unsupervised Machine Learning Techinique (Unsupervised ~ Unlabled data) where we are trying grouping of data points.These groups are called Cluster.Data points that are in the same group should have similar properties and/or features, while data points in different groups should have highly dissimilar properties and/or features.**
# *  **The aim is to segregate groups with similar traits and assign them into clusters.**
#
# ### Simple Use Case:
# > Suppose, you are the head of a rental store and wish to understand preferences of your costumers to scale up your business. Is it possible for you to look at details of each costumer and devise a unique business strategy for each one of them? Definitely not. But, what you can do is to cluster all of your costumers into say 10 groups based on their purchasing habits and use a separate strategy for costumers in each of these 10 groups. And this is what we call clustering.

# %% [markdown]
# # **Why we use Clustering? or How its helps in Data Science???**

# %% [markdown]
# * Clustering is used for things like **feature engineering** or **pattern discovery**.
# * We can use clustering analysis to gain some valuable insights from our data by seeing what groups the data points   falls.
# * Statistical Analysis of Data.
#
# ### Real-time Use-cases:
# * One of the most importat application is related to image processing. detecting distinct kinds of pattern in image data. This can be very effective in biology research, distinguishing objects and identifying patterns.
#
# * The personal data combined with shopping, location, interest, actions and a infinite number of indicators, can be analysed with this methodology, providing very important information and trends. Examples of this are the market research, marketing strategies, web analytics, and a lot of others.
#
# * Other types of applications based on clustering algorithms are climatology, robotics, recommender systems, mathematical and statistical analysis, providing a broad spectrum of utilization.
#
# ### Possible Applications
#
# * Marketing: Finding groups of customers with similar behavior given a large database of customer data containing their properties and past buying records;
#
# * Biology: Classification of plants and animals given their features;
#
# * Libraries: Book ordering;
#
# * Insurance: Identifying groups of motor insurance policy holders with a high average claim cost; identifying frauds;
#
# * City-planning: Identifying groups of houses according to their house type, value and geographical location;
#
# * Earthquake studies: Clustering observed earthquake epicenters to identify dangerous zones;
#
# * WWW document classification: Clustering weblog data to discover groups of similar access patterns.

# %% [markdown]
# ## **Clustering Visualization**
# ![image.png](attachment:ea25274c-c0b8-4f37-82ec-1103cf0b658f.png))

# %% [markdown]
# ## **Types of Clustering**
#
# ### Based on the area of overlap
# 1. **Hard Clustering**
# - Clusters don’t overlap:k-means, k-means++.Each data point either belongs to a cluster completely or not.
#
# 2. **Soft Clustering**
# - Clusters overlap:Fuzzy c-means, EM. A data object can exist in more than one cluster with a certain probability or degree of membership.
# or
# - Instead of putting each data point into a separate cluster, a probability or likelihood of that data point to be in those clusters is assigned.

# %% [markdown]
# ## A Comprehensive Survey of Clustering Algorithms.
# ##### Link : https://link.springer.com/article/10.1007/s40745-015-0040-1
# ![image.png](attachment:e93e142e-7a27-4058-980c-ff6a04aa293c.png)

# %% [markdown]
# ### **Various Clustering Algorithms:**
# ![image](https://miro.medium.com/max/875/1*S_Pkf-cK1gUE0OPbDM81ww.png)

# %% [markdown]
# ## **Lets Discuss diffrerent type of method used for clustering**

# %% [markdown]
# ## Clustering Algorithm Based on Distribution
#
# The basic idea is that the data, generated from the same distribution, belongs to the same cluster if there exists several distributions in the original data.
# The typical algorithms are DBCLASD and GMM. The core idea of DBCLASD, a dynamic incremental algorithm, is that if the distance between a cluster and its nearest data point satisfies the distribution of expected distance which is generated from the existing data points of that cluster, the nearest data point should belong to this cluster. The core idea of GMM is that GMM consists of several Gaussian distributions from which the original data is generated and the data, obeying the same independent Gaussian distribution, is considered to belong to the same cluster.
#
# #### Analysis
# ![image.png](attachment:848647f1-1146-4097-97b7-85abd4769634.png)

# %% [markdown]
# ### Advantages:
# More realistic to give the probability of belonging, relatively high scalability by changing the distribution, number of clusters and so on, and supported by the well developed statistical science;
#
# ### Disadvantages:
# The premise not completely correct, involved in many parameters which have a strong influence on the clustering result and relatively high time complexity.

# %% [markdown]
# ## Clustering Based on Density:
# The basic idea of this kind of clustering algorithms is that the data which is in the region with high density of the data space is considered to belong to the same cluster.
# The typical ones include DBSCAN, OPTICS and Mean-shift.
# * DBSCAN is the most well known density-based clustering algorithm, which is generated from the basic idea of this kind of clustering algorithms directly.
# * OPTICS is an improvement of DBSCAN and it overcomes the shortcoming of DBSCAN that being sensitive to two parameters, the radius of the neighborhood and the minimum number of points in a neighborhood.
# * In the process of Mean-shift, the mean of offset of current data point is calculated at first, the next data point is figured out based on the current data point and the offset then, and last, the iteration will be continued until some criteria are met.
# #### Analysis :
# ![DBSCAN](https://miro.medium.com/max/844/1*tc8UF-h0nQqUfLC8-0uInQ.gif)
# * ### Mean-shift
# ![Mean-shift](https://miro.medium.com/max/405/1*bkFlVrrm4HACGfUzeBnErw.gif)

# %% [markdown]
# ### Advantages:
# Clustering in high efficiency and suitable for data with arbitrary shape.
#
# ### Disadvantages:
# Resulting in a clustering result with low quality when the density of data space isn’t even, a memory with big size needed when the data volume is big, and the clustering result highly sensitive to the parameters.
#
# ### Analysis
# ![image.png](attachment:71f3a206-b36d-4cae-a38c-2a33f7ff4b5a.png)

# %% [markdown]
# ## Clustering Algorithm Based on Hierarchy
# Hierarchical clustering, as the name suggests is an algorithm that builds hierarchy of clusters. This algorithm starts with all the data points assigned to a cluster of their own. Then two nearest clusters are merged into the same cluster. In the end, this algorithm terminates when there is only a single cluster left.
#
# ![image.png](attachment:d9fba235-6abe-4f23-909d-d1d3f46c69e3.png)
#
# ### Advantages:
# Suitable for the data set with arbitrary shape and attribute of arbitrary type, the hierarchical relationship among clusters easily detected, and relatively high scalability in general;
#
# ### Disadvantages:
# Relatively high in time complexity in general, the number of clusters needed to be preset.
#
# ### Analysis
# ![image.png](attachment:5b7cabc3-0e79-4578-a523-84b4525497ff.png)

# %% [markdown]
# ## Clustering Algorithm Based on Fuzzy Theory
#
# The basic idea of this kind of clustering algorithms is that the discrete value of belonging label, {0, 1}, is changed into the continuous interval [0,1], in order to describe the belonging relationship among objects more reasonably. Typical algorithms of this kind of clustering include FCM, FCS and MM. The core idea of FCM is to get membership of each data point to every cluster by optimizing the object function. FCS, different from the traditional fuzzy clustering algorithms, takes the multidimensional hypersphere as the prototype of each cluster, so as to cluster with the distance function based on the hypersphere. MM, based on the Mountain Function, is used to find the center of cluster
#
# ### Advantages:
# More realistic to give the probability of belonging, relatively high accuracy of clustering;
#
# ### Disadvantages:
# Relatively low scalability in general, easily drawn into local optimal, the clustering result sensitive to the initial parameter values, and the number of clusters needed to be preset.
#
# ![image.png](attachment:9a11da8d-0114-465d-9385-035da0b2581b.png)
#
# ![image.png](attachment:220eb66c-1104-4c97-83ec-4b6749d99e75.png)

# %% [markdown]
# ## **Now Lets Jumps to Implementation Section**
# ### Famaous Clustering Algorithms:

# %% [markdown]
# ### 1. [K-means clustering algorithm](https://towardsdatascience.com/k-means-clustering-algorithm-applications-evaluation-methods-and-drawbacks-aa03e644b48a)
# ### 2. [DBSCAN clustering algorithm](https://www.analyticsvidhya.com/blog/2021/06/understand-the-dbscan-clustering-algorithm/)
# ### 3. [Gaussian Mixture Model algorithm](https://www.analyticsvidhya.com/blog/2019/10/gaussian-mixture-models-clustering/)
# ### 4. [BIRCH algorithm]()
# ### 5. Affinity Propagation clustering algorithm
# ### 6. Mean-Shift clustering algorithm
# ### 7. OPTICS algorithm
# ### 8. Agglomerative Hierarchy clustering algorithm

# %% [markdown]
# ## K-means clustering algorithm
#
# K-means clustering is the most commonly used clustering algorithm. It's a centroid-based algorithm and the simplest unsupervised learning algorithm.
#
# This algorithm tries to minimize the variance of data points within a cluster. It's also how most people are introduced to unsupervised machine learning.
#
# K-means is best used on smaller data sets because it iterates over all of the data points. That means it'll take more time to classify data points if there are a large amount of them in the data set.
#
# ![image.png](attachment:ab85f069-08c7-433e-b829-a52a0693de29.png)

# %% [markdown]
# ### General Implementation

# %%
from numpy import unique
from numpy import where
from matplotlib import pyplot
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans

# initialize the data set we'll work with
training_data, _ = make_classification(
    n_samples=1000,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_clusters_per_class=1,
    random_state=4
)

# define the model
kmeans_model = KMeans(n_clusters=2)

# assign each data point to a cluster
kmeans_result = kmeans_model.fit_predict(training_data)

# get all of the unique clusters
kmeans_clusters = unique(kmeans_result)

# plot the kmeans clusters
for kmeans_cluster in kmeans_clusters:
    # get data points that fall in this cluster
    index = where(kmeans_result == kmeans_cluster)
    # make the plot
    pyplot.scatter(training_data[index, 0], training_data[index, 1])

# show the kmeans plot
pyplot.show()

# %% [markdown]
# ### Lets Implement K-means Clustering as per our dataset:

# %%
#importing Library
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from sklearn import cluster
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import  LabelEncoder, RobustScaler , MinMaxScaler ,StandardScaler


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation ,Dropout
from tensorflow.keras import layers

import plotly.express as px
from scipy import signal
import scipy
#to supress warning
import warnings
warnings.filterwarnings('ignore')


#to make shell more intractive
from IPython.display import display

# setting up the chart size and background
plt.rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
sns.set_style("darkgrid")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Algorithms.docx',
#  'all-Clustering-algo.png',
#  'clustering-algorithms.ipynb',
#  'data',
#  'variousclusterimg.png']

# %%
pwd
# Out:
# 'E:\\DataScience\\Clustering-Algorithms'

# %%
path='E:\\DataScience\\Clustering-Algorithms\\data'

# %%
os.listdir(path)
# Out:
# ['data.csv', 'sample_submission.csv']

# %%
#import dataset
df =pd.read_csv(path+"\\data.csv")
sample =pd.read_csv(path+"\\sample_submission.csv")

# %%
df.head(10).style.background_gradient(cmap = 'rocket_r')
# Out:
# <style  type="text/css" >
# #T_223b5_row0_col0,#T_223b5_row1_col5,#T_223b5_row1_col22,#T_223b5_row2_col3,#T_223b5_row2_col13,#T_223b5_row2_col15,#T_223b5_row2_col25,#T_223b5_row2_col29,#T_223b5_row3_col17,#T_223b5_row3_col18,#T_223b5_row4_col4,#T_223b5_row4_col6,#T_223b5_row4_col12,#T_223b5_row4_col20,#T_223b5_row4_col24,#T_223b5_row5_col9,#T_223b5_row5_col10,#T_223b5_row5_col16,#T_223b5_row5_col23,#T_223b5_row5_col27,#T_223b5_row6_col7,#T_223b5_row6_col13,#T_223b5_row6_col14,#T_223b5_row6_col21,#T_223b5_row6_col26,#T_223b5_row7_col1,#T_223b5_row7_col13,#T_223b5_row8_col2,#T_223b5_row8_col8,#T_223b5_row8_col11,#T_223b5_row8_col17,#T_223b5_row8_col19,#T_223b5_row9_col8,#T_223b5_row9_col10,#T_223b5_row9_col11,#T_223b5_row9_col28{
#             background-color:  #faebdd;
#             color:  #000000;
#         }#T_223b5_row0_col1{
#             background-color:  #f47d57;
#             color:  #000000;
#         }#T_223b5_row0_col2,#T_223b5_row3_col26{
#             background-color:  #f6ae87;
#             color:  #000000;
#         }#T_223b5_row0_col3,#T_223b5_row7_col5{
#             background-color:  #3c1a42;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col4,#T_223b5_row0_col9{
#             background-color:  #35193e;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col5{
#             background-color:  #f58860;
#             color:  #000000;
#         }#T_223b5_row0_col6{
#             background-color:  #130d25;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col7,#T_223b5_row0_col12,#T_223b5_row0_col17,#T_223b5_row0_col26,#T_223b5_row0_col28,#T_223b5_row1_col4,#T_223b5_row1_col6,#T_223b5_row1_col13,#T_223b5_row1_col25,#T_223b5_row2_col22,#T_223b5_row2_col23,#T_223b5_row4_col8,#T_223b5_row4_col27,#T_223b5_row5_col3,#T_223b5_row5_col5,#T_223b5_row5_col18,#T_223b5_row6_col10,#T_223b5_row6_col11,#T_223b5_row6_col20,#T_223b5_row6_col29,#T_223b5_row7_col15,#T_223b5_row7_col16,#T_223b5_row7_col21,#T_223b5_row8_col1,#T_223b5_row8_col4,#T_223b5_row8_col14,#T_223b5_row8_col24,#T_223b5_row9_col0,#T_223b5_row9_col2,#T_223b5_row9_col9,#T_223b5_row9_col19{
#             background-color:  #03051a;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col8,#T_223b5_row1_col8,#T_223b5_row1_col9,#T_223b5_row6_col8,#T_223b5_row7_col8{
#             background-color:  #f6b48f;
#             color:  #000000;
#         }#T_223b5_row0_col10,#T_223b5_row6_col22,#T_223b5_row8_col26{
#             background-color:  #461c48;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col11,#T_223b5_row3_col0,#T_223b5_row6_col12,#T_223b5_row9_col12{
#             background-color:  #f06043;
#             color:  #000000;
#         }#T_223b5_row0_col13,#T_223b5_row3_col6,#T_223b5_row3_col13,#T_223b5_row4_col16,#T_223b5_row9_col13{
#             background-color:  #f58f66;
#             color:  #000000;
#         }#T_223b5_row0_col14,#T_223b5_row1_col21,#T_223b5_row4_col23{
#             background-color:  #e83f3f;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col15,#T_223b5_row3_col24{
#             background-color:  #f7cdb1;
#             color:  #000000;
#         }#T_223b5_row0_col16,#T_223b5_row1_col24{
#             background-color:  #aa185a;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col18,#T_223b5_row8_col15{
#             background-color:  #e73d3f;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col19,#T_223b5_row7_col7{
#             background-color:  #ed4e3e;
#             color:  #000000;
#         }#T_223b5_row0_col20,#T_223b5_row4_col26{
#             background-color:  #e9423e;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col21,#T_223b5_row6_col3{
#             background-color:  #f58a61;
#             color:  #000000;
#         }#T_223b5_row0_col22,#T_223b5_row5_col24{
#             background-color:  #f05c42;
#             color:  #000000;
#         }#T_223b5_row0_col23{
#             background-color:  #f6bb97;
#             color:  #000000;
#         }#T_223b5_row0_col24,#T_223b5_row2_col9,#T_223b5_row3_col8,#T_223b5_row6_col25{
#             background-color:  #701f57;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col25{
#             background-color:  #f16445;
#             color:  #000000;
#         }#T_223b5_row0_col27,#T_223b5_row3_col2{
#             background-color:  #241432;
#             color:  #f1f1f1;
#         }#T_223b5_row0_col29{
#             background-color:  #31183b;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col0,#T_223b5_row3_col15{
#             background-color:  #f6c19f;
#             color:  #000000;
#         }#T_223b5_row1_col1{
#             background-color:  #f6bf9d;
#             color:  #000000;
#         }#T_223b5_row1_col2,#T_223b5_row6_col4,#T_223b5_row9_col27{
#             background-color:  #d82748;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col3{
#             background-color:  #3a1a41;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col7{
#             background-color:  #d72549;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col10{
#             background-color:  #f26948;
#             color:  #000000;
#         }#T_223b5_row1_col11,#T_223b5_row2_col10,#T_223b5_row4_col10,#T_223b5_row7_col10,#T_223b5_row8_col7{
#             background-color:  #f4865e;
#             color:  #000000;
#         }#T_223b5_row1_col12,#T_223b5_row2_col20,#T_223b5_row4_col3,#T_223b5_row4_col28,#T_223b5_row6_col15,#T_223b5_row7_col11{
#             background-color:  #e43841;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col14,#T_223b5_row8_col23{
#             background-color:  #a11a5b;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col15,#T_223b5_row9_col23{
#             background-color:  #cf1e4d;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col16,#T_223b5_row6_col18{
#             background-color:  #f26b49;
#             color:  #000000;
#         }#T_223b5_row1_col17,#T_223b5_row5_col7,#T_223b5_row6_col19{
#             background-color:  #af1759;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col18,#T_223b5_row3_col5{
#             background-color:  #951c5b;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col19{
#             background-color:  #731f58;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col20,#T_223b5_row2_col26,#T_223b5_row4_col5{
#             background-color:  #e53940;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col23{
#             background-color:  #f6a67e;
#             color:  #000000;
#         }#T_223b5_row1_col26{
#             background-color:  #9e1a5b;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col27,#T_223b5_row3_col1,#T_223b5_row4_col15,#T_223b5_row5_col6,#T_223b5_row8_col9{
#             background-color:  #f5976e;
#             color:  #000000;
#         }#T_223b5_row1_col28{
#             background-color:  #6e1f57;
#             color:  #f1f1f1;
#         }#T_223b5_row1_col29,#T_223b5_row6_col23{
#             background-color:  #f6a37a;
#             color:  #000000;
#         }#T_223b5_row2_col0{
#             background-color:  #f5946b;
#             color:  #000000;
#         }#T_223b5_row2_col1{
#             background-color:  #251433;
#             color:  #f1f1f1;
#         }#T_223b5_row2_col2{
#             background-color:  #0d0a21;
#             color:  #f1f1f1;
#         }#T_223b5_row2_col4,#T_223b5_row4_col9,#T_223b5_row5_col8,#T_223b5_row6_col1{
#             background-color:  #e13342;
#             color:  #f1f1f1;
#         }#T_223b5_row2_col5,#T_223b5_row7_col14,#T_223b5_row9_col14{
#             background-color:  #bd1655;
#             color:  #f1f1f1;
#         }#T_223b5_row2_col6{
#             background-color:  #0b0920;
#             color:  #f1f1f1;
#         }#T_223b5_row2_col7{
#             background-color:  #170f28;
#             color:  #f1f1f1;
#         }#T_223b5_row2_col8{
#             background-color:  #ad1759;
#             color:  #f1f1f1;
#         }#T_223b5_row2_col11,#T_223b5_row3_col11{
#             background-color:  #a8185a;
#             color:  #f1f1f1;
#         }#T_223b5_row2_col12,#T_223b5_row2_col17,#T_223b5_row3_col3,#T_223b5_row3_col12,#T_223b5_row5_col14,#T_223b5_row6_col0,#T_223b5_row6_col27{
#             background-color:  #841e5a;
#             colo

# %%
df.shape
# Out:
# (98000, 30)

# %%
df.drop("id", axis=1, inplace=True)

# %%
df.describe().T.style.background_gradient(cmap = 'RdYlGn')
# Out:
# <style  type="text/css" >
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }#T_a332f_row2_col1,#T_a332f_row3_col1,#T_a332f_row4_col1,#T_a332f_row5_col1,#T_a332f_row6_col1,#T_a332f_row15_col1,#T_a332f_row18_col1,#T_a332f_row19_col1,#T_a332f_row21_col1,#T_a332f_row22_col5,#T_a332f_row22_col6,#T_a332f_row26_col5,#T_a332f_row27_col6{
#             background-color:  #b10b26;
#             color:  #f1f1f1;
#         }#T_a332f_row2_col3,#T_a332f_row14_col3{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }#T_a332f_row3_col3{
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_a332f_row4_col3,#T_a332f_row15_col3{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_a332f_row4_col4,#T_a332f_row6_col4,#T_a332f_row15_col4,#T_a332f_row18_col4,#T_a332f_row19_col4,#T_a332f_row20_col4{
#             background-color:  #d22b27;
#             color:  #f1f1f1;
#         }#T_a332f_row5_col3{
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_a332f_row5_col7,#T_a332f_row18_col7,#T_a332f_row26_col6{
#             background-color:  #ad0826;
#             color:  #f1f1f1;
#         }#T_a332f_row6_col3,#T_a332f_row19_col3{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_a332f_row7_col1{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_a332f_row7_col2{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_a332f_row7_col3,#T_a332f_row8_col3,#T_a332f_row9_col1,#T_a332f_row9_col2,#T_a332f_row9_col3,#T_a332f_row9_col6,#T_a332f_row9_col7,#T_a332f_row10_col3,#T_a332f_row10_col4,#T_a332f_row10_col6,#T_a332f_row11_col3,#T_a332f_row11_col4,#T_a332f_row11_col5,#T_a332f_row11_col6,#T_a332f_row12_col3,#T_a332f_row13_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_a332f_row7_col4,#T_a332f_row13_col4{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_a332f_row7_col5{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_a332f_row7_col6{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_a332f_row7_col7,#T_a332f_row12_col2{
#             background-color:  #a5d86a;
#             color:  #000000;
#         }#T_a332f_row8_col1{
#             background-color:  #4eb15d;
#             color:  #000000;
#         }#T_a332f_row8_col2{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_a332f_row8_col4,#T_a332f_row9_col4,#T_a332f_row12_col4{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_a332f_row8_col5,#T_a332f_row12_col5,#T_a332f_row13_col5{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_a332f_row8_col6,#T_a332f_row13_col6{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_a332f_row8_col7,#T_a332f_row11_col2,#T_a332f_row13_col7{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_a332f_row9_col5,#T_a332f_row10_col5{
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_a332f_row10_col1{
#             background-color:  #04703b;
#             color:  #f1f1f1;
#         }#T_a332f_row10_col2{
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_a332f_row10_col7{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_a332f_row11_col1{
#             background-color:  #036e3a;
#             color:  #f1f1f1;
#         }#T_a332f_row11_col7{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_a332f_row12_col1{
#             background-color:  #30a356;
#             color:  #000000;
#         }#T_a332f_row12_col6{
#             background-color:  #18954f;
#             color:  #000000;
#         }#T_a332f_row12_col7{
#             background-color:  #3faa59;
#             color:  #000000;
#         }#T_a332f_row13_col1{
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_a332f_row13_col2{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_a332f_row15_col7,#T_a332f_row16_col7,#T_a332f_row17_col7,#T_a332f_row23_col5{
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }#T_a332f_row17_col3{
#             background-color:  #fff2aa;
#             color:  #000000;
#         }#T_a332f_row18_col3{
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_a332f_row21_col3{
#             background-color:  #fff3ac;
#             color:  #000000;
#         }#T_a332f_row22_col1,#T_a332f_row25_col1,#T_a332f_row25_col4,#T_a332f_row25_col5,#T_a332f_row26_col1{
#             background-color:  #af0926;
#             color:  #f1f1f1;
#         }#T_a332f_row22_col2{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#         }#T_a332f_row22_col3{
#             background-color:  #ea5739;
#             color:  #000000;
#         }#T_a332f_row22_col4{
#             background-color:  #b71126;
#             color:  #f1f1f1;
#         }#T_a332f_row22_col7,#T_a332f_row27_col2{
#             background-color:  #c41e27;
#             color:  #f1f1f1;
#         }#T_a332f_row23_col2,#T_

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98000 entries, 0 to 97999
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   f_00    98000 non-null  float64
#  1   f_01    98000 non-null  float64
#  2   f_02    98000 non-null  float64
#  3   f_03    98000 non-null  float64
#  4   f_04    98000 non-null  float64
#  5   f_05    98000 non-null  float64
#  6   f_06    98000 non-null  float64
#  7   f_07    98000 non-null  int64
#  8   f_08    98000 non-null  int64
#  9   f_09    98000 non-null  int64
#  10  f_10    98000 non-null  int64
#  11  f_11    98000 non-null  int64
#  12  f_12    98000 non-null  int64
#  13  f_13    98000 non-null  int64
#  14  f_14    98000 non-null  float64
#  15  f_15    98000 non-null  float64
#  16  f_16    98000 non-null  float64
#  17  f_17    98000 non-null  float64
#  18  f_18    98000 non-null  float64
#  19  f_19    98000 non-null  float64
#  20  f_20    98000 non-null  float64
#  21  f_21    98000 non-null  float64
#  22  f_22    98000 non-null  float64
#  23  f_23    98000 non-null  float64
#  24  f_24    98000 non-null  float64
#  25  f_25    98000 non-null  float64
#  26  f_26    98000 non-null  float64
#  27  f_27    98000 non-null  float64
#  28  f_28    98000 non-null  float64
# dtypes: float64(22), int64(7)
# memory usage: 21.7 MB

# %%
# Correlation matrix
df.corr().style.background_gradient(cmap = 'rocket_r')
# Out:
# <style  type="text/css" >
# #T_bd986_row0_col0,#T_bd986_row1_col1,#T_bd986_row2_col2,#T_bd986_row3_col3,#T_bd986_row4_col4,#T_bd986_row5_col5,#T_bd986_row6_col6,#T_bd986_row7_col7,#T_bd986_row8_col8,#T_bd986_row9_col9,#T_bd986_row10_col10,#T_bd986_row11_col11,#T_bd986_row12_col12,#T_bd986_row13_col13,#T_bd986_row14_col14,#T_bd986_row15_col15,#T_bd986_row16_col16,#T_bd986_row17_col17,#T_bd986_row18_col18,#T_bd986_row19_col19,#T_bd986_row20_col20,#T_bd986_row21_col21,#T_bd986_row22_col22,#T_bd986_row23_col23,#T_bd986_row24_col24,#T_bd986_row25_col25,#T_bd986_row26_col26,#T_bd986_row27_col27,#T_bd986_row28_col28{
#             background-color:  #03051a;
#             color:  #f1f1f1;
#         }#T_bd986_row0_col1,#T_bd986_row0_col2,#T_bd986_row0_col3,#T_bd986_row0_col5,#T_bd986_row0_col14,#T_bd986_row0_col16,#T_bd986_row0_col18,#T_bd986_row0_col19,#T_bd986_row1_col2,#T_bd986_row1_col15,#T_bd986_row1_col17,#T_bd986_row2_col0,#T_bd986_row2_col16,#T_bd986_row2_col17,#T_bd986_row3_col0,#T_bd986_row3_col1,#T_bd986_row3_col4,#T_bd986_row3_col15,#T_bd986_row3_col19,#T_bd986_row4_col1,#T_bd986_row4_col2,#T_bd986_row4_col3,#T_bd986_row4_col16,#T_bd986_row4_col17,#T_bd986_row4_col18,#T_bd986_row4_col19,#T_bd986_row4_col20,#T_bd986_row4_col21,#T_bd986_row5_col0,#T_bd986_row5_col1,#T_bd986_row5_col20,#T_bd986_row5_col21,#T_bd986_row6_col0,#T_bd986_row6_col14,#T_bd986_row6_col20,#T_bd986_row6_col21,#T_bd986_row7_col2,#T_bd986_row7_col3,#T_bd986_row7_col5,#T_bd986_row7_col6,#T_bd986_row7_col15,#T_bd986_row7_col17,#T_bd986_row8_col3,#T_bd986_row8_col14,#T_bd986_row8_col15,#T_bd986_row8_col17,#T_bd986_row8_col18,#T_bd986_row8_col20,#T_bd986_row8_col21,#T_bd986_row9_col3,#T_bd986_row9_col4,#T_bd986_row9_col15,#T_bd986_row9_col16,#T_bd986_row9_col17,#T_bd986_row9_col18,#T_bd986_row9_col19,#T_bd986_row10_col0,#T_bd986_row10_col5,#T_bd986_row10_col15,#T_bd986_row10_col18,#T_bd986_row10_col19,#T_bd986_row10_col20,#T_bd986_row11_col1,#T_bd986_row11_col2,#T_bd986_row11_col4,#T_bd986_row11_col14,#T_bd986_row11_col15,#T_bd986_row11_col18,#T_bd986_row11_col20,#T_bd986_row11_col21,#T_bd986_row12_col4,#T_bd986_row12_col6,#T_bd986_row12_col14,#T_bd986_row12_col15,#T_bd986_row12_col18,#T_bd986_row12_col20,#
#             background-color:  #fae8d8;
#             color:  #000000;
#         }#T_bd986_row0_col7,#T_bd986_row3_col7,#T_bd986_row6_col7,#T_bd986_row17_col7,#T_bd986_row18_col7,#T_bd986_row20_col7,#T_bd986_row23_col28{
#             background-color:  #f6ad85;
#             color:  #000000;
#         }#T_bd986_row0_col8,#T_bd986_row0_col9,#T_bd986_row3_col8,#T_bd986_row4_col8,#T_bd986_row5_col8,#T_bd986_row5_col9,#T_bd986_row14_col8,#T_bd986_row15_col8,#T_bd986_row16_col9,#T_bd986_row17_col8,#T_bd986_row17_col9,#T_bd986_row18_col8,#T_bd986_row18_col9,#T_bd986_row19_col9,#T_bd986_row20_col8,#T_bd986_row21_col8{
#             background-color:  #f4815a;
#             color:  #000000;
#         }#T_bd986_row0_col10,#T_bd986_row0_col13,#T_bd986_row1_col10,#T_bd986_row2_col13,#T_bd986_row4_col13,#T_bd986_row5_col10,#T_bd986_row5_col13,#T_bd986_row6_col13,#T_bd986_

# %%
# Correlation matrix
corrMatrix =df.corr(method='pearson', min_periods=1)
corrMatrix.style.background_gradient(cmap = 'rocket_r')
# Out:
# <style  type="text/css" >
# #T_d78a4_row0_col0,#T_d78a4_row1_col1,#T_d78a4_row2_col2,#T_d78a4_row3_col3,#T_d78a4_row4_col4,#T_d78a4_row5_col5,#T_d78a4_row6_col6,#T_d78a4_row7_col7,#T_d78a4_row8_col8,#T_d78a4_row9_col9,#T_d78a4_row10_col10,#T_d78a4_row11_col11,#T_d78a4_row12_col12,#T_d78a4_row13_col13,#T_d78a4_row14_col14,#T_d78a4_row15_col15,#T_d78a4_row16_col16,#T_d78a4_row17_col17,#T_d78a4_row18_col18,#T_d78a4_row19_col19,#T_d78a4_row20_col20,#T_d78a4_row21_col21,#T_d78a4_row22_col22,#T_d78a4_row23_col23,#T_d78a4_row24_col24,#T_d78a4_row25_col25,#T_d78a4_row26_col26,#T_d78a4_row27_col27,#T_d78a4_row28_col28{
#             background-color:  #03051a;
#             color:  #f1f1f1;
#         }#T_d78a4_row0_col1,#T_d78a4_row0_col2,#T_d78a4_row0_col3,#T_d78a4_row0_col5,#T_d78a4_row0_col14,#T_d78a4_row0_col16,#T_d78a4_row0_col18,#T_d78a4_row0_col19,#T_d78a4_row1_col2,#T_d78a4_row1_col15,#T_d78a4_row1_col17,#T_d78a4_row2_col0,#T_d78a4_row2_col16,#T_d78a4_row2_col17,#T_d78a4_row3_col0,#T_d78a4_row3_col1,#T_d78a4_row3_col4,#T_d78a4_row3_col15,#T_d78a4_row3_col19,#T_d78a4_row4_col1,#T_d78a4_row4_col2,#T_d78a4_row4_col3,#T_d78a4_row4_col16,#T_d78a4_row4_col17,#T_d78a4_row4_col18,#T_d78a4_row4_col19,#T_d78a4_row4_col20,#T_d78a4_
# %%
#Classifying Catogorical and Numerical
cat_columns = [x for (x, y) in df.dtypes.items() if y == "int64"]
num_columns = [x for (x, y) in df.dtypes.items() if y == "float64"]

num_data = df[num_columns]
cat_data = df[cat_columns]
print('Categorical columns -> ', cat_columns)
print('\nNumerical columns -> ', num_columns)
# Out:
# Categorical columns ->  ['f_07', 'f_08', 'f_09', 'f_10', 'f_11', 'f_12', 'f_13']
#
# Numerical columns ->  ['f_00', 'f_01', 'f_02', 'f_03', 'f_04', 'f_05', 'f_06', 'f_14', 'f_15', 'f_16', 'f_17', 'f_18', 'f_19', 'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25', 'f_26', 'f_27', 'f_28']

# %%
def mix_plot(feature):
    plt.figure(figsize=(16, 6))
    plt.subplot(1, 3, 1)
    feature.plot(kind = 'hist')
    plt.title(f'{feature.name} histogram plot')
    #mean = feature.describe().mean()
    plt.subplot(1, 3, 2)
    mu, sigma = scipy.stats.norm.fit(feature)
    sns.distplot(feature) 
    #plt.legend({'--': mu, 'sigma': sigma})
    plt.axvline(mu, linestyle = '--', color = 'green', )
    plt.axvline(sigma, linestyle = '--', color = 'red')
    plt.title(f'{feature.name} distribution plot')
    plt.subplot(1, 3, 3)
    sns.boxplot(feature)
    plt.title(f'{feature.name} box plot')
    plt.show()

# %%
for i in cat_data.columns:
    mix_plot(cat_data[i])

# %%
import statsmodels.api as sm
fig, axs = plt.subplots(7, 2,
                        figsize=(13, 26))
for i, col in enumerate(cat_columns):
    sns.histplot(cat_data[col], ax=axs[i, 0],color='#800080')
    sm.qqplot(cat_data[col], line="s", ax=axs[i, 1], color='#800080')

# %%
from sklearn.cluster import KMeans
X = df.values
# 20 clusters
n_clusters = 20
# Train K-Means.
kmeans = KMeans(n_clusters = n_clusters, n_init = 20).fit(X)

# %%
kmeans.labels_
# Out:
# array([ 8,  7, 18, ...,  2, 13, 10])

# %%
target = kmeans.labels_

# %%
pd.DataFrame(target)[0].value_counts()
# Out:
# 10    7510
# 5     6714
# 1     6234
# 11    5984
# 2     5967
# 8     5927
# 16    5343
# 19    5322
# 15    5189
# 14    5170
# 18    5026
# 0     5011
# 12    4496
# 4     4196
# 9     4183
# 13    3970
# 6     3436
# 3     3256
# 7     2677
# 17    2389
# Name: 0, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler,RobustScaler
sc = StandardScaler()
rb = RobustScaler()

##Scaling of Data
rb.fit(df)
df = rb.transform(df)
df.shape, target.shape
# Out:
# ((98000, 29), (98000,))

# %%
#creating_neural_network
model =Sequential()
#1st_hidden_layers
model.add(Dense(units=256, activation='relu', use_bias=True, kernel_initializer='he_uniform',input_shape=(29,)))
#2nd_hidden_layers
model.add(Dense(units=128,activation='relu',kernel_initializer='he_uniform'))
model.add(layers.Dropout(0.25))
#3rd_hidden_layers
model.add(Dense(units=128,activation='relu',kernel_initializer='he_uniform'))
model.add(layers.Dropout(0.25))
#4nd_hidden_layers
model.add(Dense(units=64,activation='relu',kernel_initializer='he_uniform'))
#5th_hidden_layers
model.add(Dense(units=32,activation='relu',kernel_initializer='he_uniform'))
#6th_hidden_layer
model.add(Dense(units=20,activation='softmax',kernel_initializer='glorot_uniform'))
#model complile
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy',])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               7680
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 20)                660
#
# =================================================================
# Total params: 68,084
# Trainable params: 68,084
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers
# Out:
# [<keras.layers.core.dense.Dense at 0x1e63dd74370>,
#  <keras.layers.core.dense.Dense at 0x1e63dd74a60>,
#  <keras.layers.core.dropout.Dropout at 0x1e63ddb4a60>,
#  <keras.layers.core.dense.Dense at 0x1e630fc2700>,
#  <keras.layers.core.dropout.Dropout at 0x1e630fc2ee0>,
#  <keras.layers.core.dense.Dense at 0x1e630fc27f0>,
#  <keras.layers.core.dense.Dense at 0x1e63113ce20>,
#  <keras.layers.core.dense.Dense at 0x1e631151f10>]

# %%
save_best = tf.keras.callbacks.ModelCheckpoint("Model.h5", verbose=1, monitor='val_accuracy', save_best_only=True)

# %%
#model traning
model.fit(df, target, validation_split=0.2, epochs=30, batch_size=256, shuffle=True, callbacks=[save_best])
# Out:
# Epoch 1/30
# 296/307 [===========================>..] - ETA: 0s - loss: 2.9110 - accuracy: 0.0968
# Epoch 1: val_accuracy improved from -inf to 0.23673, saving model to Model.h5
# 307/307 [==============================] - 6s 7ms/step - loss: 2.9013 - accuracy: 0.0996 - val_loss: 2.4914 - val_accuracy: 0.2367
# Epoch 2/30
# 299/307 [============================>.] - ETA: 0s - loss: 2.1158 - accuracy: 0.3024
# Epoch 2: val_accuracy improved from 0.23673 to 0.53745, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 2.1071 - accuracy: 0.3046 - val_loss: 1.3987 - val_accuracy: 0.5374
# Epoch 3/30
# 305/307 [============================>.] - ETA: 0s - loss: 1.4481 - accuracy: 0.4977
# Epoch 3: val_accuracy improved from 0.53745 to 0.67255, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 1.4477 - accuracy: 0.4980 - val_loss: 0.9609 - val_accuracy: 0.6726
# Epoch 4/30
# 299/307 [============================>.] - ETA: 0s - loss: 1.1500 - accuracy: 0.5914
# Epoch 4: val_accuracy improved from 0.67255 to 0.73628, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 1.1479 - accuracy: 0.5923 - val_loss: 0.7446 - val_accuracy: 0.7363
# Epoch 5/30
# 305/307 [============================>.] - ETA: 0s - loss: 0.9854 - accuracy: 0.6421
# Epoch 5: val_accuracy improved from 0.73628 to 0.77342, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.9849 - accuracy: 0.6423 - val_loss: 0.6407 - val_accuracy: 0.7734
# Epoch 6/30
# 303/307 [============================>.] - ETA: 0s - loss: 0.8920 - accuracy: 0.6727
# Epoch 6: val_accuracy improved from 0.77342 to 0.78980, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.8912 - accuracy: 0.6733 - val_loss: 0.5839 - val_accuracy: 0.7898
# Epoch 7/30
# 302/307 [============================>.] - ETA: 0s - loss: 0.8240 - accuracy: 0.6961
# Epoch 7: val_accuracy improved from 0.78980 to 0.80306, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.8236 - accuracy: 0.6961 - val_loss: 0.5398 - val_accuracy: 0.8031
# Epoch 8/30
# 301/307 [============================>.] - ETA: 0s - loss: 0.7770 - accuracy: 0.7107
# Epoch 8: val_accuracy improved from 0.80306 to 0.81209, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.7773 - accuracy: 0.7108 - val_loss: 0.5110 - val_accuracy: 0.8121
# Epoch 9/30
# 297/307 [============================>.] - ETA: 0s - loss: 0.7395 - accuracy: 0.7221
# Epoch 9: val_accuracy improved from 0.81209 to 0.82281, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.7388 - accuracy: 0.7226 - val_loss: 0.4819 - val_accuracy: 0.8228
# Epoch 10/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.7003 - accuracy: 0.7372
# Epoch 10: val_accuracy improved from 0.82281 to 0.82980, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.7002 - accuracy: 0.7373 - val_loss: 0.4613 - val_accuracy: 0.8298
# Epoch 11/30
# 307/307 [==============================] - ETA: 0s - loss: 0.6740 - accuracy: 0.7470
# Epoch 11: val_accuracy improved from 0.82980 to 0.83520, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.6740 - accuracy: 0.7470 - val_loss: 0.4456 - val_accuracy: 0.8352
# Epoch 12/30
# 307/307 [==============================] - ETA: 0s - loss: 0.6497 - accuracy: 0.7564
# Epoch 12: val_accuracy improved from 0.83520 to 0.84077, saving model to Model.h5
# 307/307 [==============================] - 2s 7ms/step - loss: 0.6497 - accuracy: 0.7564 - val_loss: 0.4283 - val_accuracy: 0.8408
# Epoch 13/30
# 305/307 [============================>.] - ETA: 0s - loss: 0.6258 - accuracy: 0.7644
# Epoch 13: val_accuracy improved from 0.84077 to 0.84138, saving model to Model.h5
# 307/307 [==============================] - 2s 7ms/step - loss: 0.6258 - accuracy: 0.7643 - val_loss: 0.4179 - val_accuracy: 0.8414
# Epoch 14/30
# 304/307 [============================>.] - ETA: 0s - loss: 0.6106 - accuracy: 0.7702
# Epoch 14: val_accuracy improved from 0.84138 to 0.84949, saving model to Model.h5
# 307/307 [==============================] - 2s 7ms/step - loss: 0.6105 - accuracy: 0.7703 - val_loss: 0.4056 - val_accuracy: 0.8495
# Epoch 15/30
# 298/307 [============================>.] - ETA: 0s - loss: 0.5971 - accuracy: 0.7741
# Epoch 15: val_accuracy improved from 0.84949 to 0.85577, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.5968 - accuracy: 0.7743 - val_loss: 0.3921 - val_accuracy: 0.8558
# Epoch 16/30
# 296/307 [===========================>..] - ETA: 0s - loss: 0.5778 - accuracy: 0.7811
# Epoch 16: val_accuracy did not improve from 0.85577
# 307/307 [==============================] - 2s 5ms/step - loss: 0.5772 - accuracy: 0.7813 - val_loss: 0.3878 - val_accuracy: 0.8547
# Epoch 17/30
# 304/307 [============================>.] - ETA: 0s - loss: 0.5594 - accuracy: 0.7885
# Epoch 17: val_accuracy improved from 0.85577 to 0.86250, saving model to Model.h5
# 307/307 [==============================] - 2s 5ms/step - loss: 0.5599 - accuracy: 0.7883 - val_loss: 0.3720 - val_accuracy: 0.8625
# Epoch 18/30
# 298/307 [============================>.] - ETA: 0s - loss: 0.5561 - accuracy: 0.7911
# Epoch 18: val_accuracy did not improve from 0.86250
# 307/307 [==============================] - 2s 5ms/step - loss: 0.5547 - accuracy: 0.7918 - val_loss: 0.3713 - val_accuracy: 0.8612
# Epoch 19/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.5395 - accuracy: 0.7950
# Epoch 19: val_accuracy improved from 0.86250 to 0.86648, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.5395 - accuracy: 0.7950 - val_loss: 0.3600 - val_accuracy: 0.8665
# Epoch 20/30
# 304/307 [============================>.] - ETA: 0s - loss: 0.5252 - accuracy: 0.8009
# Epoch 20: val_accuracy improved from 0.86648 to 0.86939, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.5252 - accuracy: 0.8010 - val_loss: 0.3504 - val_accuracy: 0.8694
# Epoch 21/30
# 296/307 [===========================>..] - ETA: 0s - loss: 0.5187 - accuracy: 0.8035
# Epoch 21: val_accuracy improved from 0.86939 to 0.87209, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.5184 - accuracy: 0.8038 - val_loss: 0.3450 - val_accuracy: 0.8721
# Epoch 22/30
# 307/307 [==============================] - ETA: 0s - loss: 0.5066 - accuracy: 0.8081
# Epoch 22: val_accuracy improved from 0.87209 to 0.87480, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.5066 - accuracy: 0.8081 - val_loss: 0.3386 - val_accuracy: 0.8748
# Epoch 23/30
# 303/307 [============================>.] - ETA: 0s - loss: 0.4957 - accuracy: 0.8117
# Epoch 23: val_accuracy improved from 0.87480 to 0.87806, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4957 - accuracy: 0.8117 - val_loss: 0.3347 - val_accuracy: 0.8781
# Epoch 24/30
# 305/307 [============================>.] - ETA: 0s - loss: 0.4873 - accuracy: 0.8157
# Epoch 24: val_accuracy improved from 0.87806 to 0.87867, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4873 - accuracy: 0.8158 - val_loss: 0.3270 - val_accuracy: 0.8787
# Epoch 25/30
# 299/307 [============================>.] - ETA: 0s - loss: 0.4757 - accuracy: 0.8186
# Epoch 25: val_accuracy improved from 0.87867 to 0.88158, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4761 - accuracy: 0.8185 - val_loss: 0.3214 - val_accuracy: 0.8816
# Epoch 26/30
# 303/307 [============================>.] - ETA: 0s - loss: 0.4699 - accuracy: 0.8211
# Epoch 26: val_accuracy improved from 0.88158 to 0.88383, saving model to Model.h5
# 307/307 [==============================] - 2s 5ms/step - loss: 0.4697 - accuracy: 0.8211 - val_loss: 0.3157 - val_accuracy: 0.8838
# Epoch 27/30
# 307/307 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.8231
# Epoch 27: val_accuracy did not improve from 0.88383
# 307/307 [==============================] - 2s 5ms/step - loss: 0.4639 - accuracy: 0.8231 - val_loss: 0.3152 - val_accuracy: 0.8819
# Epoch 28/30
# 298/307 [============================>.] - ETA: 0s - loss: 0.4560 - accuracy: 0.8251
# Epoch 28: val_accuracy improved from 0.88383 to 0.88684, saving model to Model.h5
# 307/307 [==============================] - 2s 5ms/step - loss: 0.4566 - accuracy: 0.8251 - val_loss: 0.3096 - val_accuracy: 0.8868
# Epoch 29/30
# 296/307 [===========================>..] - ETA: 0s - loss: 0.4481 - accuracy: 0.8295
# Epoch 29: val_accuracy improved from 0.88684 to 0.88857, saving model to Model.h5
# 307/307 [==============================] - 2s 5ms/step - loss: 0.4480 - accuracy: 0.8297 - val_loss: 0.3042 - val_accuracy: 0.8886
# Epoch 30/30
# 298/307 [============================>.] - ETA: 0s - loss: 0.4429 - accuracy: 0.8329
# Epoch 30: val_accuracy improved from 0.88857 to 0.89107, saving model to Model.h5
# 307/307 [==============================] - 2s 5ms/step - loss: 0.4429 - accuracy: 0.8332 - val_loss: 0.2990 - val_accuracy: 0.8911

# %%
history =model.fit(df, target, validation_split=0.2, epochs=30, batch_size=256, shuffle=True, callbacks=[save_best])
# Out:
# Epoch 1/30
# 296/307 [===========================>..] - ETA: 0s - loss: 0.4330 - accuracy: 0.8350
# Epoch 1: val_accuracy improved from 0.89107 to 0.89122, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4332 - accuracy: 0.8351 - val_loss: 0.2952 - val_accuracy: 0.8912
# Epoch 2/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.4254 - accuracy: 0.8375
# Epoch 2: val_accuracy improved from 0.89122 to 0.89235, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4255 - accuracy: 0.8376 - val_loss: 0.2906 - val_accuracy: 0.8923
# Epoch 3/30
# 307/307 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8380
# Epoch 3: val_accuracy did not improve from 0.89235
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4215 - accuracy: 0.8380 - val_loss: 0.2885 - val_accuracy: 0.8923
# Epoch 4/30
# 303/307 [============================>.] - ETA: 0s - loss: 0.4138 - accuracy: 0.8416
# Epoch 4: val_accuracy improved from 0.89235 to 0.89495, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4138 - accuracy: 0.8416 - val_loss: 0.2821 - val_accuracy: 0.8949
# Epoch 5/30
# 299/307 [============================>.] - ETA: 0s - loss: 0.4117 - accuracy: 0.8417
# Epoch 5: val_accuracy improved from 0.89495 to 0.89730, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4115 - accuracy: 0.8418 - val_loss: 0.2784 - val_accuracy: 0.8973
# Epoch 6/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.4085 - accuracy: 0.8447
# Epoch 6: val_accuracy improved from 0.89730 to 0.89750, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4083 - accuracy: 0.8448 - val_loss: 0.2768 - val_accuracy: 0.8975
# Epoch 7/30
# 301/307 [============================>.] - ETA: 0s - loss: 0.4015 - accuracy: 0.8463
# Epoch 7: val_accuracy improved from 0.89750 to 0.89801, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.4015 - accuracy: 0.8463 - val_loss: 0.2735 - val_accuracy: 0.8980
# Epoch 8/30
# 300/307 [============================>.] - ETA: 0s - loss: 0.3972 - accuracy: 0.8486
# Epoch 8: val_accuracy did not improve from 0.89801
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3974 - accuracy: 0.8484 - val_loss: 0.2728 - val_accuracy: 0.8978
# Epoch 9/30
# 307/307 [==============================] - ETA: 0s - loss: 0.3915 - accuracy: 0.8506
# Epoch 9: val_accuracy improved from 0.89801 to 0.90092, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3915 - accuracy: 0.8506 - val_loss: 0.2680 - val_accuracy: 0.9009
# Epoch 10/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.3876 - accuracy: 0.8512
# Epoch 10: val_accuracy improved from 0.90092 to 0.90153, saving model to Model.h5
# 307/307 [==============================] - 2s 7ms/step - loss: 0.3877 - accuracy: 0.8511 - val_loss: 0.2649 - val_accuracy: 0.9015
# Epoch 11/30
# 302/307 [============================>.] - ETA: 0s - loss: 0.3840 - accuracy: 0.8526
# Epoch 11: val_accuracy did not improve from 0.90153
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3835 - accuracy: 0.8529 - val_loss: 0.2644 - val_accuracy: 0.9009
# Epoch 12/30
# 304/307 [============================>.] - ETA: 0s - loss: 0.3782 - accuracy: 0.8550
# Epoch 12: val_accuracy improved from 0.90153 to 0.90327, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3781 - accuracy: 0.8550 - val_loss: 0.2597 - val_accuracy: 0.9033
# Epoch 13/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.3717 - accuracy: 0.8578
# Epoch 13: val_accuracy did not improve from 0.90327
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3716 - accuracy: 0.8579 - val_loss: 0.2587 - val_accuracy: 0.9031
# Epoch 14/30
# 301/307 [============================>.] - ETA: 0s - loss: 0.3675 - accuracy: 0.8599
# Epoch 14: val_accuracy did not improve from 0.90327
# 307/307 [==============================] - 2s 7ms/step - loss: 0.3677 - accuracy: 0.8599 - val_loss: 0.2569 - val_accuracy: 0.9033
# Epoch 15/30
# 303/307 [============================>.] - ETA: 0s - loss: 0.3684 - accuracy: 0.8599
# Epoch 15: val_accuracy improved from 0.90327 to 0.90776, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3679 - accuracy: 0.8600 - val_loss: 0.2501 - val_accuracy: 0.9078
# Epoch 16/30
# 302/307 [============================>.] - ETA: 0s - loss: 0.3643 - accuracy: 0.8618
# Epoch 16: val_accuracy did not improve from 0.90776
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3641 - accuracy: 0.8619 - val_loss: 0.2508 - val_accuracy: 0.9047
# Epoch 17/30
# 298/307 [============================>.] - ETA: 0s - loss: 0.3607 - accuracy: 0.8616
# Epoch 17: val_accuracy did not improve from 0.90776
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3606 - accuracy: 0.8615 - val_loss: 0.2496 - val_accuracy: 0.9052
# Epoch 18/30
# 301/307 [============================>.] - ETA: 0s - loss: 0.3577 - accuracy: 0.8624
# Epoch 18: val_accuracy did not improve from 0.90776
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3573 - accuracy: 0.8626 - val_loss: 0.2469 - val_accuracy: 0.9071
# Epoch 19/30
# 298/307 [============================>.] - ETA: 0s - loss: 0.3518 - accuracy: 0.8655
# Epoch 19: val_accuracy did not improve from 0.90776
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3519 - accuracy: 0.8656 - val_loss: 0.2444 - val_accuracy: 0.9076
# Epoch 20/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.3454 - accuracy: 0.8670
# Epoch 20: val_accuracy did not improve from 0.90776
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3456 - accuracy: 0.8669 - val_loss: 0.2453 - val_accuracy: 0.9076
# Epoch 21/30
# 298/307 [============================>.] - ETA: 0s - loss: 0.3392 - accuracy: 0.8702
# Epoch 21: val_accuracy improved from 0.90776 to 0.90929, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3392 - accuracy: 0.8702 - val_loss: 0.2395 - val_accuracy: 0.9093
# Epoch 22/30
# 305/307 [============================>.] - ETA: 0s - loss: 0.3394 - accuracy: 0.8685
# Epoch 22: val_accuracy improved from 0.90929 to 0.90985, saving model to Model.h5
# 307/307 [==============================] - 2s 7ms/step - loss: 0.3394 - accuracy: 0.8686 - val_loss: 0.2389 - val_accuracy: 0.9098
# Epoch 23/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.3368 - accuracy: 0.8714
# Epoch 23: val_accuracy improved from 0.90985 to 0.91082, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3368 - accuracy: 0.8713 - val_loss: 0.2375 - val_accuracy: 0.9108
# Epoch 24/30
# 307/307 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8709
# Epoch 24: val_accuracy did not improve from 0.91082
# 307/307 [==============================] - 2s 7ms/step - loss: 0.3367 - accuracy: 0.8709 - val_loss: 0.2354 - val_accuracy: 0.9104
# Epoch 25/30
# 303/307 [============================>.] - ETA: 0s - loss: 0.3333 - accuracy: 0.8706
# Epoch 25: val_accuracy did not improve from 0.91082
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3333 - accuracy: 0.8704 - val_loss: 0.2351 - val_accuracy: 0.9106
# Epoch 26/30
# 306/307 [============================>.] - ETA: 0s - loss: 0.3309 - accuracy: 0.8732
# Epoch 26: val_accuracy improved from 0.91082 to 0.91403, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3309 - accuracy: 0.8732 - val_loss: 0.2312 - val_accuracy: 0.9140
# Epoch 27/30
# 303/307 [============================>.] - ETA: 0s - loss: 0.3284 - accuracy: 0.8744
# Epoch 27: val_accuracy did not improve from 0.91403
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3278 - accuracy: 0.8747 - val_loss: 0.2309 - val_accuracy: 0.9133
# Epoch 28/30
# 299/307 [============================>.] - ETA: 0s - loss: 0.3242 - accuracy: 0.8743
# Epoch 28: val_accuracy did not improve from 0.91403
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3245 - accuracy: 0.8742 - val_loss: 0.2288 - val_accuracy: 0.9131
# Epoch 29/30
# 297/307 [============================>.] - ETA: 0s - loss: 0.3239 - accuracy: 0.8753
# Epoch 29: val_accuracy improved from 0.91403 to 0.91474, saving model to Model.h5
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3244 - accuracy: 0.8751 - val_loss: 0.2286 - val_accuracy: 0.9147
# Epoch 30/30
# 296/307 [===========================>..] - ETA: 0s - loss: 0.3206 - accuracy: 0.8761
# Epoch 30: val_accuracy did not improve from 0.91474
# 307/307 [==============================] - 2s 6ms/step - loss: 0.3200 - accuracy: 0.8762 - val_loss: 0.2261 - val_accuracy: 0.9147

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(30)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#Model Prediction
pred = model.predict(df, verbose=1)
pred = np.argmax(pred, axis=1)
# Out:
# 3063/3063 [==============================] - 6s 2ms/step

# %%
#Predicting of Clusters
pd.DataFrame(pred)[0].value_counts()
# Out:
# 10    7294
# 5     6518
# 1     6258
# 2     5965
# 8     5884
# 11    5884
# 16    5529
# 19    5404
# 15    5364
# 14    5206
# 0     5133
# 18    4806
# 12    4617
# 9     4293
# 4     4107
# 13    3831
# 6     3410
# 3     3212
# 7     2824
# 17    2461
# Name: 0, dtype: int64

# %%
sample['Predicted'] = kmeans.labels_
sample.to_csv('submission.csv', index=False)

# %%
sample
# Out:
#           Id  Predicted
# 0          0          8
# 1          1          7
# 2          2         18
# 3          3         11
# 4          4         12
# ...      ...        ...
# 97995  97995          5
# 97996  97996         12
# 97997  97997          2
# 97998  97998         13
# 97999  97999         10
#
# [98000 rows x 2 columns]

# %% [markdown]
#  ### Working in other clustering algorithms....
