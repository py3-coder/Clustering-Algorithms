# %% [markdown]
# ### Author ~ Saurabh Kumar

# %% [markdown]
# # **Lets First UnderStand Clustering**

# %% [markdown]
# # **What is Clustering?**

# %% [markdown]
# ### Defination:
# * **Clustering is Unsupervised Machine Learning Techinique (Unsupervised ~ Unlabled data) where we are trying grouping of data points.These groups are called Cluster.Data points that are in the same group should have similar properties and/or features, while data points in different groups should have highly dissimilar properties and/or features.**
# *  **The aim is to segregate groups with similar traits and assign them into clusters.**
#
# ### Simple Use Case:
# > Suppose, you are the head of a rental store and wish to understand preferences of your costumers to scale up your business. Is it possible for you to look at details of each costumer and devise a unique business strategy for each one of them? Definitely not. But, what you can do is to cluster all of your costumers into say 10 groups based on their purchasing habits and use a separate strategy for costumers in each of these 10 groups. And this is what we call clustering.

# %% [markdown]
# # **Why we use Clustering? or How its helps in Data Science???**

# %% [markdown]
# * Clustering is used for things like **feature engineering** or **pattern discovery**.
# * We can use clustering analysis to gain some valuable insights from our data by seeing what groups the data points   falls.
# * Statistical Analysis of Data.
#
# ### Real-time Use-cases:
# * One of the most importat application is related to image processing. detecting distinct kinds of pattern in image data. This can be very effective in biology research, distinguishing objects and identifying patterns.
#
# * The personal data combined with shopping, location, interest, actions and a infinite number of indicators, can be analysed with this methodology, providing very important information and trends. Examples of this are the market research, marketing strategies, web analytics, and a lot of others.
#
# * Other types of applications based on clustering algorithms are climatology, robotics, recommender systems, mathematical and statistical analysis, providing a broad spectrum of utilization.
#
# ### Possible Applications
#
# * Marketing: Finding groups of customers with similar behavior given a large database of customer data containing their properties and past buying records;
#
# * Biology: Classification of plants and animals given their features;
#
# * Libraries: Book ordering;
#
# * Insurance: Identifying groups of motor insurance policy holders with a high average claim cost; identifying frauds;
#
# * City-planning: Identifying groups of houses according to their house type, value and geographical location;
#
# * Earthquake studies: Clustering observed earthquake epicenters to identify dangerous zones;
#
# * WWW document classification: Clustering weblog data to discover groups of similar access patterns.

# %% [markdown]
# ## **Clustering Visualization**
# ![image.png](attachment:ea25274c-c0b8-4f37-82ec-1103cf0b658f.png))

# %% [markdown]
# ## **Types of Clustering**
#
# ### Based on the area of overlap
# 1. **Hard Clustering**
# - Clusters don’t overlap:k-means, k-means++.Each data point either belongs to a cluster completely or not.
#
# 2. **Soft Clustering**
# - Clusters overlap:Fuzzy c-means, EM. A data object can exist in more than one cluster with a certain probability or degree of membership.
# or
# - Instead of putting each data point into a separate cluster, a probability or likelihood of that data point to be in those clusters is assigned.

# %% [markdown]
# ## A Comprehensive Survey of Clustering Algorithms.
# ##### Link : https://link.springer.com/article/10.1007/s40745-015-0040-1
# ![image.png](attachment:e93e142e-7a27-4058-980c-ff6a04aa293c.png)

# %% [markdown]
# ### **Various Clustering Algorithms:**
# ![image](https://miro.medium.com/max/875/1*S_Pkf-cK1gUE0OPbDM81ww.png)

# %% [markdown]
# ## **Lets Discuss diffrerent type of method used for clustering**

# %% [markdown]
# ## Clustering Algorithm Based on Distribution
#
# The basic idea is that the data, generated from the same distribution, belongs to the same cluster if there exists several distributions in the original data.
# The typical algorithms are DBCLASD and GMM. The core idea of DBCLASD, a dynamic incremental algorithm, is that if the distance between a cluster and its nearest data point satisfies the distribution of expected distance which is generated from the existing data points of that cluster, the nearest data point should belong to this cluster. The core idea of GMM is that GMM consists of several Gaussian distributions from which the original data is generated and the data, obeying the same independent Gaussian distribution, is considered to belong to the same cluster.
#
# #### Analysis
# ![image.png](attachment:848647f1-1146-4097-97b7-85abd4769634.png)

# %% [markdown]
# ### Advantages:
# More realistic to give the probability of belonging, relatively high scalability by changing the distribution, number of clusters and so on, and supported by the well developed statistical science;
#
# ### Disadvantages:
# The premise not completely correct, involved in many parameters which have a strong influence on the clustering result and relatively high time complexity.

# %% [markdown]
# ## Clustering Based on Density:
# The basic idea of this kind of clustering algorithms is that the data which is in the region with high density of the data space is considered to belong to the same cluster.
# The typical ones include DBSCAN, OPTICS and Mean-shift.
# * DBSCAN is the most well known density-based clustering algorithm, which is generated from the basic idea of this kind of clustering algorithms directly.
# * OPTICS is an improvement of DBSCAN and it overcomes the shortcoming of DBSCAN that being sensitive to two parameters, the radius of the neighborhood and the minimum number of points in a neighborhood.
# * In the process of Mean-shift, the mean of offset of current data point is calculated at first, the next data point is figured out based on the current data point and the offset then, and last, the iteration will be continued until some criteria are met.
# #### Analysis :
# ![DBSCAN](https://miro.medium.com/max/844/1*tc8UF-h0nQqUfLC8-0uInQ.gif)

# %% [markdown]
# * ###  Mean-shift
# ![Mean-shift](https://miro.medium.com/max/405/1*bkFlVrrm4HACGfUzeBnErw.gif)

# %% [markdown]
# ### Advantages:
# Clustering in high efficiency and suitable for data with arbitrary shape.
#
# ### Disadvantages:
# Resulting in a clustering result with low quality when the density of data space isn’t even, a memory with big size needed when the data volume is big, and the clustering result highly sensitive to the parameters.
#
# ### Analysis
# ![image.png](attachment:71f3a206-b36d-4cae-a38c-2a33f7ff4b5a.png)

# %% [markdown]
# ## Clustering Algorithm Based on Hierarchy
# Hierarchical clustering, as the name suggests is an algorithm that builds hierarchy of clusters. This algorithm starts with all the data points assigned to a cluster of their own. Then two nearest clusters are merged into the same cluster. In the end, this algorithm terminates when there is only a single cluster left.
#
# ![image.png](attachment:d9fba235-6abe-4f23-909d-d1d3f46c69e3.png)
#
# ### Advantages:
# Suitable for the data set with arbitrary shape and attribute of arbitrary type, the hierarchical relationship among clusters easily detected, and relatively high scalability in general;
#
# ### Disadvantages:
# Relatively high in time complexity in general, the number of clusters needed to be preset.
#
# ### Analysis
# ![image.png](attachment:5b7cabc3-0e79-4578-a523-84b4525497ff.png)

# %% [markdown]
# ## Clustering Algorithm Based on Fuzzy Theory
#
# The basic idea of this kind of clustering algorithms is that the discrete value of belonging label, {0, 1}, is changed into the continuous interval [0,1], in order to describe the belonging relationship among objects more reasonably. Typical algorithms of this kind of clustering include FCM, FCS and MM. The core idea of FCM is to get membership of each data point to every cluster by optimizing the object function. FCS, different from the traditional fuzzy clustering algorithms, takes the multidimensional hypersphere as the prototype of each cluster, so as to cluster with the distance function based on the hypersphere. MM, based on the Mountain Function, is used to find the center of cluster
#
# ### Advantages:
# More realistic to give the probability of belonging, relatively high accuracy of clustering;
#
# ### Disadvantages:
# Relatively low scalability in general, easily drawn into local optimal, the clustering result sensitive to the initial parameter values, and the number of clusters needed to be preset.
#
# ![image.png](attachment:9a11da8d-0114-465d-9385-035da0b2581b.png)
#
# ![image.png](attachment:220eb66c-1104-4c97-83ec-4b6749d99e75.png)

# %% [markdown]
# ## **Now Lets Jumps to Implementation Section**
# ### Famaous Clustering Algorithms:

# %% [markdown]
# ### 1. [K-means clustering algorithm](https://towardsdatascience.com/k-means-clustering-algorithm-applications-evaluation-methods-and-drawbacks-aa03e644b48a)
# ### 2. [DBSCAN clustering algorithm](https://www.analyticsvidhya.com/blog/2021/06/understand-the-dbscan-clustering-algorithm/)
# ### 3. [Gaussian Mixture Model algorithm](https://www.analyticsvidhya.com/blog/2019/10/gaussian-mixture-models-clustering/)
# ### 4. [BIRCH algorithm]()
# ### 5. Affinity Propagation clustering algorithm
# ### 6. Mean-Shift clustering algorithm
# ### 7. OPTICS algorithm
# ### 8. Agglomerative Hierarchy clustering algorithm

# %% [markdown]
# ## K-means clustering algorithm
#
# K-means clustering is the most commonly used clustering algorithm. It's a centroid-based algorithm and the simplest unsupervised learning algorithm.
#
# This algorithm tries to minimize the variance of data points within a cluster. It's also how most people are introduced to unsupervised machine learning.
#
# K-means is best used on smaller data sets because it iterates over all of the data points. That means it'll take more time to classify data points if there are a large amount of them in the data set.
#
# ![image.png](attachment:ab85f069-08c7-433e-b829-a52a0693de29.png)

# %% [markdown]
# ### General Implementation

# %%
### Worked on other Sample data to show the Working of k-mean Cluster Algorithm:
from numpy import unique
from numpy import where
from matplotlib import pyplot
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans

# initialize the data set we'll work with
training_data, _ = make_classification(
    n_samples=1000,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_clusters_per_class=1,
    random_state=4
)

# define the model
kmeans_model = KMeans(n_clusters=3)

# assign each data point to a cluster
kmeans_result = kmeans_model.fit_predict(training_data)

# get all of the unique clusters
kmeans_clusters = unique(kmeans_result)

# plot the kmeans clusters
for kmeans_cluster in kmeans_clusters:
    # get data points that fall in this cluster
    index = where(kmeans_result == kmeans_cluster)
    # make the plot
    pyplot.scatter(training_data[index, 0], training_data[index, 1])

# show the kmeans plot
pyplot.show()

# %% [markdown]
# ### Lets Implement K-means Clustering:

# %%
#importing Library
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from sklearn import cluster
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.mixture import BayesianGaussianMixture
from sklearn.preprocessing import  LabelEncoder, RobustScaler , MinMaxScaler ,StandardScaler
from yellowbrick.cluster import KElbowVisualizer


import plotly.express as px
from scipy import signal
import scipy
#to supress warning
import warnings
warnings.filterwarnings('ignore')


#to make shell more intractive
from IPython.display import display

# setting up the chart size and background
plt.rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
sns.set_style("darkgrid")

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Algorithms.docx',
#  'all-Clustering-algo.png',
#  'Clustering-algorithms.ipynb',
#  'data',
#  'submission.csv',
#  'submission_1_gmm.csv',
#  'submission_ggm_2.csv',
#  'submission_gmm.csv',
#  'variousclusterimg.png']

# %%
pwd
# Out:
# 'E:\\DataScience\\Clustering~Algorithms'

# %%
path ='E:\\DataScience\\Clustering~Algorithms\\data'

# %%
#import dataset
df =pd.read_csv(path+"\\data.csv")
sample =pd.read_csv(path+"\\sample_submission.csv")

# %%
df.head(10).style.background_gradient(cmap = 'rocket_r')
# Out:
# <style  type="text/css" >
# #T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col0,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col5,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col22,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row2_col3,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row2_col13,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row2_col15,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row2_col25,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row2_col29,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col17,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col18,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col4,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col6,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col12,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col20,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col24,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col9,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col10,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col16,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col23,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col27,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col7,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col13,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col14,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col21,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col26,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row7_col1,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row7_col13,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col2,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col8,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col11,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col17,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col19,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col8,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col10,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col11,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col28{
#             background-color:  #faebdd;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col1{
#             background-color:  #f47d57;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col2,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col26{
#             background-color:  #f6ae87;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col3,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row7_col5{
#             background-color:  #3c1a42;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col4,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col9{
#             background-color:  #35193e;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col5{
#             background-color:  #f58860;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col6{
#             background-color:  #130d25;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col7,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col12,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col17,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col26,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col28,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col4,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col6,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col13,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col25,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row2_col22,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row2_col23,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col8,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col27,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col3,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col5,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col18,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col10,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col11,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col20,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col29,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row7_col15,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row7_col16,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row7_col21,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col1,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col4,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col14,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col24,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col0,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col2,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col9,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col19{
#             background-color:  #03051a;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col8,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col8,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col9,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col8,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row7_col8{
#             background-color:  #f6b48f;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col10,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col22,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col26{
#             background-color:  #461c48;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col11,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col0,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col12,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col12{
#             background-color:  #f06043;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col13,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col6,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col13,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col16,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row9_col13{
#             background-color:  #f58f66;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col14,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col21,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col23{
#             background-color:  #e83f3f;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col15,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col24{
#             background-color:  #f7cdb1;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col16,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col24{
#             background-color:  #aa185a;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col18,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row8_col15{
#             background-color:  #e73d3f;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col19,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row7_col7{
#             background-color:  #ed4e3e;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col20,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row4_col26{
#             background-color:  #e9423e;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col21,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col3{
#             background-color:  #f58a61;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col22,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row5_col24{
#             background-color:  #f05c42;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col23{
#             background-color:  #f6bb97;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col24,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row2_col9,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col8,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row6_col25{
#             background-color:  #701f57;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col25{
#             background-color:  #f16445;
#             color:  #000000;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col27,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row3_col2{
#             background-color:  #241432;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row0_col29{
#             background-color:  #31183b;
#             color:  #f1f1f1;
#         }#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row1_col0,#T_4cec97e8_fc20_11ec_8c7c_088fc3092891row

# %%
df.shape
# Out:
# (98000, 30)

# %%
df.drop("id", axis=1, inplace=True)

# %%
df.describe().T.style.background_gradient(cmap = 'RdYlGn')
# Out:
# <style  type="text/css" >
# #T_4dadc662_fc20_11ec_9758_088fc3092891row0_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row0_col2,#T_4dadc662_fc20_11ec_9758_088fc3092891row0_col6,#T_4dadc662_fc20_11ec_9758_088fc3092891row1_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row1_col2,#T_4dadc662_fc20_11ec_9758_088fc3092891row1_col6,#T_4dadc662_fc20_11ec_9758_088fc3092891row2_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row2_col2,#T_4dadc662_fc20_11ec_9758_088fc3092891row2_col6,#T_4dadc662_fc20_11ec_9758_088fc3092891row3_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row3_col2,#T_4dadc662_fc20_11ec_9758_088fc3092891row3_col6,#T_4dadc662_fc20_11ec_9758_088fc3092891row4_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row4_col2,#T_4dadc662_fc20_11ec_9758_088fc3092891row4_col6,#T_4dadc662_fc20_11ec_9758_088fc3092891row4_col7,#T_4dadc662_fc20_11ec_9758_088fc3092891row5_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row5_col2,#T_4dadc662_fc20_11ec_9758_088fc3092891row5_col6,#T_4dadc662_fc20_11ec_9758_088fc3092891row6_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row6_col2,#T_4dadc662_fc20_11ec_9758_088fc3092891row6_col6,#T_4dadc662_fc20_11ec_9758_088fc3092891row6_col7,#T_4dadc662_fc20_11ec_9758_088fc3092891row7_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row8_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row9_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row10_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row11_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row12_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row13_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row14_col0,#T_4dadc662_fc20_11ec_9758_088fc3092891row14_col2,#
#             background-color:  #b10b26;
#             color:  #f1f1f1;
#         }#T_4dadc662_fc20_11ec_9758_088fc3092891row2_col3,#T_4dadc662_fc20_11ec_9758_088fc3092891row14_col3{
#             background-color:  #fff5ae;
#             color:  #000000;
#         }#T_4dadc662_fc20_11ec_9758_088fc3092891row3_col3{
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_4dadc662_fc20_11ec_9758_088fc3092891row4_col3,#T_4dadc662_fc20_11ec_9758_088fc3092891row15_col3{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_4dadc662_fc20_11ec_9758_088fc3092891row4_col4,#T_4dadc662_fc20_11ec_9758_088fc3092891row6_col4,#T_4dadc662_fc20_11ec_9758_088fc3092891row15_col4,#T_4dadc662_fc20_11ec_9758_088fc3092891row18_col4,#T_4dadc662_fc20_11ec_9758_088fc3092891row19_col4,#T_4dadc662_fc20_11ec_9758_088fc3092891row20_col4{
#             background-color:  #d22b27;
#             color:  #f1f1f1;
#         }#T_4dadc662_fc20_11ec_9758_088fc3092891row5_col3{
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_4dadc662_fc20_11ec_9758_088fc3092891row5_col7,#T_4dadc662_fc20_11ec_9758

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98000 entries, 0 to 97999
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   f_00    98000 non-null  float64
#  1   f_01    98000 non-null  float64
#  2   f_02    98000 non-null  float64
#  3   f_03    98000 non-null  float64
#  4   f_04    98000 non-null  float64
#  5   f_05    98000 non-null  float64
#  6   f_06    98000 non-null  float64
#  7   f_07    98000 non-null  int64
#  8   f_08    98000 non-null  int64
#  9   f_09    98000 non-null  int64
#  10  f_10    98000 non-null  int64
#  11  f_11    98000 non-null  int64
#  12  f_12    98000 non-null  int64
#  13  f_13    98000 non-null  int64
#  14  f_14    98000 non-null  float64
#  15  f_15    98000 non-null  float64
#  16  f_16    98000 non-null  float64
#  17  f_17    98000 non-null  float64
#  18  f_18    98000 non-null  float64
#  19  f_19    98000 non-null  float64
#  20  f_20    98000 non-null  float64
#  21  f_21    98000 non-null  float64
#  22  f_22    98000 non-null  float64
#  23  f_23    98000 non-null  float64
#  24  f_24    98000 non-null  float64
#  25  f_25    98000 non-null  float64
#  26  f_26    98000 non-null  float64
#  27  f_27    98000 non-null  float64
#  28  f_28    98000 non-null  float64
# dtypes: float64(22), int64(7)
# memory usage: 21.7 MB

# %%
# Correlation matrix
corrMatrix =df.corr(method='pearson', min_periods=1)
corrMatrix.style.background_gradient(cmap = 'rocket_r')
# Out:
# <style  type="text/css" >
_11ec_b941_088fc3092891row8_col17,#T_4eb8e424_fc20_11ec_b941_088fc3092891row8_col18,#T_4eb8e424_fc20_11ec_b941_088fc3092891row8_col19,#T_4eb8e424_fc20_11ec_b941_088fc3092891row8_col20,#T_4eb8e424_fc20_11ec_b941_088fc3092891row8_col21,#T_4eb8e424_fc20_11ec_b941_088fc3092891row9_col15,#T_4eb8e424_fc20_11ec_b941_088fc3092891row9_col17,#T_4eb8e424_fc20_11ec_b941_088fc3092891row9_col18,#T_4eb8e424_fc20_11ec_b941_088fc3092891row9_col19,#T_4eb8e424_fc20_11ec_b941_088fc3092891row9_col21,#T_4eb8e424_fc20_11ec_b941_088fc3092891row10_col0,#T_4eb8e424_fc20_11ec_b941_088fc3092891row10_col3,#T_4eb8e424_fc20_11ec_b941_088fc3092891row10_col5,#T_4eb8e424_fc20_11ec_b941_088fc3092891row10_col15,#T_4eb8e424_fc20_11ec_b941_088fc3092891row10_col18,#T_4eb8e424_fc20_11ec_b941_088fc3092891row10_col19,#T_4eb8e424_fc20_11ec_b941_088fc3092891row11_col1,#T_4eb8e424_fc20_11ec_b941_088fc3092891row11_col2,#T_4eb8e424_fc20_11ec_b941_088fc3092891row11_col4,#T_4eb8e424_fc20_11ec_b941_088fc3092891row11_col14,#T_4eb8e424_fc20_11ec_b941_088fc3092891row11_col15,#T_4eb8e424_fc20_11ec_b941_088fc3092891row11_col18,#T_4eb8e424_fc20_11ec_b941_088fc3092891row11_col20,#T_4eb8e424_fc20_11ec_b941_088fc3092891row11_col21,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col2,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col3,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col4,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col5,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col6,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col14,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col15,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col18,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col20,#T_4eb8e424_fc20_11ec_b941_088fc3092891row12_col ...

# %%
#Classifying Catogorical and Numerical
cat_columns = [x for (x, y) in df.dtypes.items() if y == "int64"]
num_columns = [x for (x, y) in df.dtypes.items() if y == "float64"]

num_data = df[num_columns]
cat_data = df[cat_columns]
print('Categorical columns -> ', cat_columns)
print('\nNumerical columns -> ', num_columns)
# Out:
# Categorical columns ->  ['f_07', 'f_08', 'f_09', 'f_10', 'f_11', 'f_12', 'f_13']
#
# Numerical columns ->  ['f_00', 'f_01', 'f_02', 'f_03', 'f_04', 'f_05', 'f_06', 'f_14', 'f_15', 'f_16', 'f_17', 'f_18', 'f_19', 'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25', 'f_26', 'f_27', 'f_28']

# %%
def mix_plot(feature):
    plt.figure(figsize=(16, 6))
    plt.subplot(1, 3, 1)
    feature.plot(kind = 'hist')
    plt.title(f'{feature.name} histogram plot')
    #mean = feature.describe().mean()
    plt.subplot(1, 3, 2)
    mu, sigma = scipy.stats.norm.fit(feature)
    sns.distplot(feature) 
    #plt.legend({'--': mu, 'sigma': sigma})
    plt.axvline(mu, linestyle = '--', color = 'green', )
    plt.axvline(sigma, linestyle = '--', color = 'red')
    plt.title(f'{feature.name} distribution plot')
    plt.subplot(1, 3, 3)
    sns.boxplot(feature)
    plt.title(f'{feature.name} box plot')
    plt.show()

# %%
for i in cat_data.columns:
    mix_plot(cat_data[i])

# %%
import statsmodels.api as sm
fig, axs = plt.subplots(7, 2,
                        figsize=(13, 26))
for i, col in enumerate(cat_columns):
    sns.histplot(cat_data[col], ax=axs[i, 0],color='#800080')
    sm.qqplot(cat_data[col], line="s", ax=axs[i, 1], color='#800080')

# %%
ss = StandardScaler()
data = ss.fit_transform(cat_data)

# %%
inertias = pd.Series(name='inertia')
for n_clusters in range(2,20):
    km = KMeans(n_clusters=n_clusters)
    km.fit(data)
    data_pred = km.predict(data)
    inertias[str(n_clusters)] = km.inertia_

# %%
inertias.plot(title='elbow');

# %%
n_clusters = 6
km = KMeans(n_clusters=n_clusters)
km.fit(data)
data_pred = km.predict(data)

# %%
sample["Predicted"] = data_pred
sample.to_csv('submission_kmean.csv',index=False)

# %%
sample
# Out:
#           Id  Predicted
# 0          0          4
# 1          1          2
# 2          2          4
# 3          3          3
# 4          4          1
# ...      ...        ...
# 97995  97995          1
# 97996  97996          1
# 97997  97997          5
# 97998  97998          0
# 97999  97999          2
#
# [98000 rows x 2 columns]

# %% [markdown]
# ## GMM (Gaussian Mixture Model algorithm)

# %%
#scaling 
scaler = RobustScaler()
X_scaled = scaler.fit_transform(df)

# %%
km = KMeans(random_state=1)
# k is range of number of clusters.
visualizer = KElbowVisualizer(km, k=(4,12), timings=True)
visualizer.fit(X_scaled)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
gmm = BayesianGaussianMixture(n_components=7, covariance_type='full', random_state=1)
preds = gmm.fit_predict(X_scaled)

# %%
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(X_scaled)
df = pd.DataFrame({"x" : reduced_data[:,0], "y" : reduced_data[:,1], "clusters" : preds})
plt.figure(figsize=(20, 10))
sns.scatterplot(x=df["x"], y=df["y"], hue=df["clusters"])
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sample["Predicted"] = preds
sample.to_csv('submission_gmm.csv', index=False)

# %%
sample
# Out:
#           Id  Predicted
# 0          0          6
# 1          1          1
# 2          2          6
# 3          3          4
# 4          4          2
# ...      ...        ...
# 97995  97995          1
# 97996  97996          2
# 97997  97997          5
# 97998  97998          5
# 97999  97999          3
#
# [98000 rows x 2 columns]

# %% [markdown]
# ##  Implemetation of DBSCAN clustering algorithm

# %%
#importing DBSCAN from sklearn lib
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

# %%
# Scaling the data to bring all the attributes to a comparable level
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
# Normalizing the data so that 
# the data approximately follows a Gaussian distribution
normalized_data = normalize(scaled_data)
  
# Converting the numpy array into a pandas DataFrame
normalized_data = pd.DataFrame(normalized_data)

# %%
#Reducing the dimensionality of the data to make it visualizable
pca = PCA(n_components = 2)
data_principal = pca.fit_transform(normalized_data)
data_principal = pd.DataFrame(data_principal)
data_principal.columns = ['P1', 'P2']

# %%
data_principal.head(10).style.background_gradient(cmap = 'rocket_r')
# Out:
# <style  type="text/css" >
# #T_50383c08_fc24_11ec_8353_088fc3092891row0_col0{
#             background-color:  #211330;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row0_col1{
#             background-color:  #781f59;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row1_col0,#T_50383c08_fc24_11ec_8353_088fc3092891row4_col1,#T_50383c08_fc24_11ec_8353_088fc3092891row5_col0{
#             background-color:  #faebdd;
#             color:  #000000;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row1_col1{
#             background-color:  #a8185a;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row2_col0{
#             background-color:  #4e1d4b;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row2_col1{
#             background-color:  #f16445;
#             color:  #000000;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row3_col0,#T_50383c08_fc24_11ec_8353_088fc3092891row6_col1{
#             background-color:  #03051a;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row3_col1{
#             background-color:  #ea443e;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row4_col0{
#             background-color:  #f7cdb1;
#             color:  #000000;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row5_col1{
#             background-color:  #ef5840;
#             color:  #000000;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row6_col0{
#             background-color:  #37193f;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row7_col0{
#             background-color:  #1e122d;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row7_col1{
#             background-color:  #f8d3ba;
#             color:  #000000;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row8_col0{
#             background-color:  #f8dcc7;
#             color:  #000000;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row8_col1{
#             background-color:  #661f54;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row9_col0{
#             background-color:  #7d1f5a;
#             color:  #f1f1f1;
#         }#T_50383c08_fc24_11ec_8353_088fc3092891row9_col1{
#             background-color:  #f4845d;
#             color:  #000000;
#         }</style><table id="T_50383c08_fc24_11ec_8353_088fc3092891" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P1</th>        <th class="col_heading level0 col1" >P2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row0_col0" class="data row0 col0" >0.691844</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row0_col1" class="data row0 col1" >0.254412</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row1_col0" class="data row1 col0" >-0.937892</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row1_col1" class="data row1 col1" >0.148696</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row2_col0" class="data row2 col0" >0.483320</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row2_col1" class="data row2 col1" >-0.095971</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row3_col0" class="data row3 col0" >0.846899</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row3_col1" class="data row3 col1" >-0.039612</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row4_col0" class="data row4 col0" >-0.793257</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row4_col1" class="data row4 col1" >-0.410322</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row5_col0" class="data row5 col0" >-0.937964</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row5_col1" class="data row5 col1" >-0.074349</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row6_col0" class="data row6 col0" >0.585470</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row6_col1" class="data row6 col1" >0.547751</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row7_col0" class="data row7 col0" >0.701799</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row7_col1" class="data row7 col1" >-0.347791</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row8_col0" class="data row8 col0" >-0.867304</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row8_col1" class="data row8 col1" >0.295233</td>
#             </tr>
#             <tr>
#                         <th id="T_50383c08_fc24_11ec_8353_088fc3092891level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row9_col0" class="data row9 col0" >0.282061</td>
#                         <td id="T_50383c08_fc24_11ec_8353_088fc3092891row9_col1" class="data row9 col1" >-0.165389</td>
#             </tr>
#     </tbody></table>

# %%
#Building the clustering model
# Numpy array of all the cluster labels assigned to each data point
db_default = DBSCAN(eps =10, min_samples = 5).fit(data_principal)
labels = db_default.labels_

# %%
labels

# %% [markdown]
#  ## Still in Working Phase....
#
#  **If you like this my work ..Kindly upvote and share to others....**
# #  Thanks for visiting my notebooks
